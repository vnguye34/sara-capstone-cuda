# %% [markdown]
# **Tutorial from this article:**
# https://towardsdatascience.com/understanding-audio-data-fourier-transform-fft-spectrogram-and-speech-recognition-a4072d228520
#
# **Library Imports**

# %%
# !conda install -c conda-forge librosa
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/sarasoueidan/opt/anaconda3/envs/dsi
#
#   added / updated specs:
#     - librosa
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     audioread-2.1.4            |           py35_1          24 KB  conda-forge
#     blas-2.12                  |         openblas          10 KB  conda-forge
#     bzip2-1.0.8                |       h0b31af3_2         152 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     cffi-1.11.5                |   py35h5e8e0c9_1         210 KB  conda-forge
#     cycler-0.10.0              |             py_2           9 KB  conda-forge
#     decorator-4.4.2            |             py_0          11 KB  conda-forge
#     ffmpeg-4.2.3               |       hd0c0d6a_0        52.0 MB  conda-forge
#     freetype-2.10.2            |       h8da9a1a_0         874 KB  conda-forge
#     gettext-0.19.8.1           |    h46ab8bc_1002         3.3 MB  conda-forge
#     gmp-6.2.0                  |       h4a8c4bd_2         788 KB  conda-forge
#     gnutls-3.6.13              |       hc269f14_0         2.1 MB  conda-forge
#     joblib-0.14.1              |     pyh9f0ad1d_0         198 KB  conda-forge
#     kiwisolver-1.0.1           |   py35h2d50403_2          65 KB  conda-forge
#     libblas-3.8.0              |      12_openblas          10 KB  conda-forge
#     libcblas-3.8.0             |      12_openblas          10 KB  conda-forge
#     libflac-1.3.3              |       h4a8c4bd_0         351 KB  conda-forge
#     libgfortran-3.0.1          |                0         495 KB  conda-forge
#     libiconv-1.15              |    h0b31af3_1006         1.3 MB  conda-forge
#     liblapack-3.8.0            |      12_openblas          10 KB  conda-forge
#     liblapacke-3.8.0           |      12_openblas          10 KB  conda-forge
#     libopenblas-0.3.7          |       hd44dcd8_1         8.4 MB  conda-forge
#     libpng-1.6.37              |       hbbe82c9_1         295 KB  conda-forge
#     libsndfile-1.0.28          |    h4a8c4bd_1000         540 KB  conda-forge
#     libvorbis-1.3.6            |       h4a8c4bd_2         245 KB  conda-forge
#     llvmlite-0.25.0            |           py35_0         8.7 MB  conda-forge
#     matplotlib-3.0.0           |   py35h54f8f79_0         4.9 MB
#     numba-0.40.0               |   py35hf8a1672_0         2.6 MB  conda-forge
#     numpy-1.15.2               |   py35h926163e_0          46 KB
#     numpy-base-1.15.2          |   py35ha711998_0         3.3 MB
#     openh264-2.1.1             |       hd174df1_0         1.5 MB  conda-forge
#     openssl-1.0.2u             |       h0b31af3_0         3.1 MB  conda-forge
#     pip-20.1.1                 |             py_1         1.1 MB  conda-forge
#     pycparser-2.20             |             py_0          89 KB  conda-forge
#     pyparsing-2.4.7            |     pyh9f0ad1d_0          60 KB  conda-forge
#     scikit-learn-0.20.0        |   py35hebd9d1a_1         4.0 MB
#     scipy-1.1.0                |   py35h1a1e112_1        11.6 MB
#     six-1.15.0                 |     pyh9f0ad1d_0          14 KB  conda-forge
#     tornado-5.1.1              |   py35h470a237_0         663 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       113.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   audioread          conda-forge/osx-64::audioread-2.1.4-py35_1
#   blas               conda-forge/osx-64::blas-2.12-openblas
#   bzip2              conda-forge/osx-64::bzip2-1.0.8-h0b31af3_2
#   cffi               conda-forge/osx-64::cffi-1.11.5-py35h5e8e0c9_1
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   decorator          conda-forge/noarch::decorator-4.4.2-py_0
#   ffmpeg             conda-forge/osx-64::ffmpeg-4.2.3-hd0c0d6a_0
#   freetype           conda-forge/osx-64::freetype-2.10.2-h8da9a1a_0
#   gettext            conda-forge/osx-64::gettext-0.19.8.1-h46ab8bc_1002
#   gmp                conda-forge/osx-64::gmp-6.2.0-h4a8c4bd_2
#   gnutls             conda-forge/osx-64::gnutls-3.6.13-hc269f14_0
#   joblib             conda-forge/noarch::joblib-0.14.1-pyh9f0ad1d_0
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.0.1-py35h2d50403_2
#   lame               conda-forge/osx-64::lame-3.100-h1de35cc_1001
#   libblas            conda-forge/osx-64::libblas-3.8.0-12_openblas
#   libcblas           conda-forge/osx-64::libcblas-3.8.0-12_openblas
#   libflac            conda-forge/osx-64::libflac-1.3.3-h4a8c4bd_0
#   libgfortran        conda-forge/osx-64::libgfortran-3.0.1-0
#   libiconv           conda-forge/osx-64::libiconv-1.15-h0b31af3_1006
#   liblapack          conda-forge/osx-64::liblapack-3.8.0-12_openblas
#   liblapacke         conda-forge/osx-64::liblapacke-3.8.0-12_openblas
#   libogg             conda-forge/osx-64::libogg-1.3.2-h0b31af3_1002
#   libopenblas        conda-forge/osx-64::libopenblas-0.3.7-hd44dcd8_1
#   libpng             conda-forge/osx-64::libpng-1.6.37-hbbe82c9_1
#   librosa            conda-forge/noarch::librosa-0.7.2-py_0
#   libsndfile         conda-forge/osx-64::libsndfile-1.0.28-h4a8c4bd_1000
#   libvorbis          conda-forge/osx-64::libvorbis-1.3.6-h4a8c4bd_2
#   llvmlite           conda-forge/osx-64::llvmlite-0.25.0-py35_0
#   matplotlib         pkgs/main/osx-64::matplotlib-3.0.0-py35h54f8f79_0
#   nettle             conda-forge/osx-64::nettle-3.4.1-h3efe00b_1002
#   numba              conda-forge/osx-64::numba-0.40.0-py35hf8a1672_0
#   numpy              pkgs/main/osx-64::numpy-1.15.2-py35h926163e_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.15.2-py35ha711998_0
#   openh264           conda-forge/osx-64::openh264-2.1.1-hd174df1_0
#   pip                conda-forge/noarch::pip-20.1.1-py_1
#   pycparser          conda-forge/noarch::pycparser-2.20-py_0
#   pyparsing          conda-forge/noarch::pyparsing-2.4.7-pyh9f0ad1d_0
#   pysoundfile        conda-forge/noarch::pysoundfile-0.10.2-py_1001
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.1-py_0
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   resampy            conda-forge/noarch::resampy-0.2.2-py_0
#   scikit-learn       pkgs/main/osx-64::scikit-learn-0.20.0-py35hebd9d1a_1
#   scipy              pkgs/main/osx-64::scipy-1.1.0-py35h1a1e112_1
#   six                conda-forge/noarch::six-1.15.0-pyh9f0ad1d_0
#   tornado            conda-forge/osx-64::tornado-5.1.1-py35h470a237_0
#   x264               conda-forge/osx-64::x264-1!152.20180806-h1de35cc_0
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.4.5.1-hecc5488_0
#   certifi               pkgs/main::certifi-2018.8.24-py35_1 --> conda-forge::certifi-2018.8.24-py35_1001
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl              pkgs/main::openssl-1.0.2u-h1de35cc_0 --> conda-forge::openssl-1.0.2u-h0b31af3_0
#
#
# Proceed ([y]/n)?

# %%
# !y
